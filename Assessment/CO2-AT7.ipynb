# %% [markdown]
# <a href="https://colab.research.google.com/github/prathap0655/CSA6102/blob/main/Assessment/CO2-AT7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def detect_bruteforce(log_lines, threshold=5):
    ip_counts = {}
    for line in log_lines:
        if 'FAILED LOGIN' in line:
            parts = line.split(' ')
            ip = parts[4]
            if ip not in ip_counts:
                ip_counts[ip] = 0
            ip_counts[ip] += 1
    flagged = []
    for ip, count in ip_counts.items():
        if count >= threshold:
            flagged.append(ip)
    return flagged
log = [
    'FAILED LOGIN user=admin from 10.0.0.5',
    'FAILED LOGIN user=admin from 10.0.0.5',
    'FAILED LOGIN user=root from 10.0.0.5'
]
print(detect_bruteforce(log, threshold=2))
# Out:
# ['10.0.0.5']
