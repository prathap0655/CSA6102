# %% [markdown]
# <a href="https://colab.research.google.com/github/prathap0655/CSA6102/blob/main/Assessment/CO2-AT5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def classify_incident(description):
    categories = {
        'Phishing': ['fake email', 'login link', 'credential'],
        'Ransomware': ['encrypted files', 'ransom note', 'bitcoin'],
        'Identity Theft': ['stolen identity', 'aadhaar', 'pan card'],
        'Cyberstalking': ['harassment', 'repeated messages', 'online stalking']
    }
    description = description.lower()
    for category, keywords in categories.items():
        for word in keywords:
            if word in description:
                return category
    return 'Unclassified'
result = classify_incident('Victim received a fake email with a login link')
print(result)
# Out:
# Phishing
