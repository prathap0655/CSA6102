# %% [markdown]
# <a href="https://colab.research.google.com/github/prathap0655/CSA6102/blob/main/Assessment/CO2-AT9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
volatile_sources = ['RAM', 'Cache', 'Running Processes', 'Network Connections', 'Swap File']
def classify(source):
    if source in volatile_sources:
        return 'Volatile'
    else:
        return 'Non-Volatile'
evidence_sources = ['RAM', 'Hard Disk', 'Cache', 'Registry Files']
for src in evidence_sources:
    print(src, ':', classify(src))
# Out:
# RAM : Volatile
# Hard Disk : Non-Volatile
# Cache : Volatile
# Registry Files : Non-Volatile
